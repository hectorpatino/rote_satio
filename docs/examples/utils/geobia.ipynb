# %%
from rote_satio.utils.geobia_transformer import SegmentsTransformer
import rioxarray

# %%
image = rioxarray.open_rasterio('../../../data/2018-12_11001_01.tif', engine='rasterio')
image
# Out:
# <xarray.DataArray (band: 4, y: 524, x: 524)> Size: 2MB
# [1098304 values with dtype=uint16]
# Coordinates:
#   * band         (band) int32 16B 1 2 3 4
#   * x            (x) float64 4kB -8.257e+06 -8.257e+06 ... -8.254e+06 -8.254e+06
#   * y            (y) float64 4kB 5.071e+05 5.071e+05 ... 5.046e+05 5.046e+05
#     spatial_ref  int32 4B 0
# Attributes:
#     AREA_OR_POINT:             Area
#     STATISTICS_MAXIMUM:        4386
#     STATISTICS_MEAN:           817.39244872094
#     STATISTICS_MINIMUM:        0
#     STATISTICS_STDDEV:         420.9740595041
#     STATISTICS_VALID_PERCENT:  100
#     scale_factor:              1.0
#     add_offset:                0.0
#     long_name:                 ('B', 'G', 'R', 'N')

# %%
segments_transformer = SegmentsTransformer()
image = segments_transformer.fit_transform(image)
image
# Out:
# D:\Dev\segmentador\segmentador\src\rote_satio\utils\geobia_transformer.py:28: FutureWarning: This transformer does not need to be fitted. It will return self.
#   warnings.warn("This transformer does not need to be fitted. It will return self.", FutureWarning)
# <xarray.DataArray (band: 4, y: 524, x: 524)> Size: 2MB
# [1098304 values with dtype=uint16]
# Coordinates:
#   * band         (band) int32 16B 1 2 3 4
#   * x            (x) float64 4kB -8.257e+06 -8.257e+06 ... -8.254e+06 -8.254e+06
#   * y            (y) float64 4kB 5.071e+05 5.071e+05 ... 5.046e+05 5.046e+05
#     spatial_ref  int32 4B 0
# Attributes:
#     AREA_OR_POINT:             Area
#     STATISTICS_MAXIMUM:        4386
#     STATISTICS_MEAN:           817.39244872094
#     STATISTICS_MINIMUM:        0
#     STATISTICS_STDDEV:         420.9740595041
#     STATISTICS_VALID_PERCENT:  100
#     scale_factor:              1.0
#     add_offset:                0.0
#     long_name:                 [1, 2, 3, 4]
